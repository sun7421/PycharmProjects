# %%
import numpy as np#จัดการตัวเลขarray
import pandas as pd
import yfinance
from matplotlib import pyplot as plt
import talib
import pandas_datareader as web
import datetime
from datetime import datetime
from datetime import timedelta

# %%
x = pd.read_excel('stocksun.xlsm')

# %%
freefloat = 35
valuek = 5000
netprofit=0
set_ema0=20
set_ema1=50
set_ema2=200
set_rsi=58

# %%
#check freefloat

# %%
number=x.shape[0]
number
# Out:
# 762

# %%
i=0
e=0
while e< number:
    y=x.iloc[i,18]
    if y<=freefloat :
         i+=1
         e+=1
    else : 
         x = x.drop(e,axis=0)
         x.reset_index(drop=True) # Reset index
         e+=1   
print("finish")
# Out:
# finish

# %%
x.to_csv('freefloat_scan.csv')
x
# Out:
#        Name    No.          Links  Sign   Last  Chg%     Volume  Value (k)  \
# 2    3K-BAT    2.0              i   NaN  67.50  0.00        0.0        0.0
# 4         A    4.0  i | 1 | 2 | 3   NaN   4.98  0.00     2500.0       12.0
# 5        A5    5.0      i | 1 | 3  SPNC   1.50  0.00        0.0        0.0
# 7     ABICO    7.0  i | 1 | 2 | 3   NaN   5.15 -1.90    56100.0      286.0
# 8       ABM    8.0      i | 1 | 3   NaN   1.43 -4.03  1616000.0     2332.0
# ..      ...    ...            ...   ...    ...   ...        ...        ...
# 753     WPH  753.0  i | 1 | 2 | 3   NaN   2.14 -6.96  1332000.0     2923.0
# 754      WR  754.0      i | 1 | 3   NaN   0.35  0.00        0.0        0.0
# 758     YGG  758.0      i | 1 | 3   NaN  20.70 -1.43   481700.0     9971.0
# 759   YUASA  759.0      i | 1 | 3   NaN  17.30 -1.70    95800.0     1663.0
# 760     ZEN  760.0      i | 1 | 3   NaN  11.50 -1.71    92600.0     1060.0
#
#      MCap (M)     P/E  ... FFloat%  MG%  Magic1  Magic2   PEG  CG        rsi  \
# 2      5292.0  198.86  ...    2.10  NaN   999.0     NaN   NaN NaN        NaN
# 4      4880.0   30.79  ...   25.86  NaN   784.0   779.0 -0.12 NaN        NaN
# 5      1685.0     NaN  ...   20.60  NaN     NaN     NaN   NaN NaN        NaN
# 7      1259.0   28.48  ...   27.66  NaN   765.0   760.0 -0.27 NaN        NaN
# 8       429.0   48.96  ...   34.68  NaN   936.0   927.0 -0.26 NaN        NaN
# ..        ...     ...  ...     ...  ...     ...     ...   ...  ..        ...
# 753    1284.0     NaN  ...   29.57  NaN     NaN     NaN   NaN NaN        NaN
# 754     872.0     NaN  ...    2.96  NaN     NaN     NaN   NaN NaN        NaN
# 758    3726.0   63.05  ...   26.32  NaN   627.0   555.0  3.86 NaN        NaN
# 759    1862.0   11.53  ...   15.27  NaN   225.0   177.0  0.30 NaN        NaN
# 760    3450.0  381.98  ...   26.68  NaN  1068.0  1081.0 -4.15 NaN        NaN
#
#     Ema20  Ema50  Ema200
# 2     NaN    NaN     NaN
# 4     NaN    NaN     NaN
# 5     NaN    NaN     NaN
# 7     NaN    NaN     NaN
# 8     NaN    NaN     NaN
# ..    ...    ...     ...
# 753   NaN    NaN     NaN
# 754   NaN    NaN     NaN
# 758   NaN    NaN     NaN
# 759   NaN    NaN     NaN
# 760   NaN    NaN     NaN
#
# [334 rows x 28 columns]

# %%
#check value(k)

# %%
a=pd.read_csv('freefloat_scan.csv')
x=a.iloc[0:,1:]

# %%
number=x.shape[0]
number
# Out:
# 334

# %%
 y=x.iloc[0,7]
y
# Out:
# 0.0

# %%
i=0
e=0
while e< number:
    y=x.iloc[i,7]
    if y > valuek :
         i+=1
         e+=1
    else : 
         x = x.drop(e,axis=0)
         x.reset_index(drop=True) # Reset index
         e+=1   
print("finish")
# Out:
# finish

# %%
x.to_csv('value_scan.csv')
x
# Out:
#        Name    No.          Links Sign    Last  Chg%      Volume  Value (k)  \
# 5       ACE   11.0      i | 1 | 3  NaN    3.92  0.00  93454200.0   365854.0
# 7       AEC   16.0      i | 1 | 3    C    7.85 -1.26   3129900.0    24535.0
# 8    AEONTS   17.0  i | 1 | 2 | 3  NaN  186.00 -1.33   1237400.0   231962.0
# 10      AIE   24.0  i | 1 | 2 | 3  NaN    1.33 -3.62  18802000.0    25246.0
# 12      ALL   31.0      i | 1 | 3  NaN    3.14  1.95  22535100.0    69730.0
# ..      ...    ...            ...  ...     ...   ...         ...        ...
# 322     VPO  738.0      i | 1 | 3  NaN    1.22 -3.17   4254600.0     5238.0
# 326   WHAUP  745.0  i | 1 | 2 | 3  NaN    4.28 -1.38   4389500.0    18954.0
# 327     WIN  748.0  i | 1 | 2 | 3  NaN    0.85  0.00  27581700.0    23456.0
# 328  WINMED  749.0              i  NaN    6.90  0.00  15266300.0   104544.0
# 331     YGG  758.0      i | 1 | 3  NaN   20.70 -1.43    481700.0     9971.0
#
#      MCap (M)     P/E  ... FFloat%  MG%  Magic1  Magic2    PEG  CG        rsi  \
# 5     39890.0   31.30  ...   22.62  NaN   600.0   555.0   0.37 NaN        NaN
# 7     11274.0     NaN  ...   25.59  NaN     NaN     NaN    NaN NaN        NaN
# 8     46500.0   10.79  ...   30.86  NaN   142.0   298.0   1.25 NaN        NaN
# 10     6959.0   14.90  ...   26.00  NaN   264.0   230.0  -0.10 NaN        NaN
# 12     2109.0   37.01  ...   27.52  NaN   891.0   833.0 -12.74 NaN        NaN
# ..        ...     ...  ...     ...  ...     ...     ...    ...  ..        ...
# 322    1147.0  339.16  ...   32.22  NaN  1066.0  1018.0 -21.88 NaN        NaN
# 326   16371.0   18.19  ...   25.59  NaN   578.0   605.0   0.19 NaN        NaN
# 327     477.0     NaN  ...   31.53  NaN     NaN     NaN    NaN NaN        NaN
# 328       0.0     NaN  ...   28.83  NaN     NaN     NaN    NaN NaN        NaN
# 331    3726.0   63.05  ...   26.32  NaN   627.0   555.0   3.86 NaN        NaN
#
#     Ema20  Ema50  Ema200
# 5     NaN    NaN     NaN
# 7     NaN    NaN     NaN
# 8     NaN    NaN     NaN
# 10    NaN    NaN     NaN
# 12    NaN    NaN     NaN
# ..    ...    ...     ...
# 322   NaN    NaN     NaN
# 326   NaN    NaN     NaN
# 327   NaN    NaN     NaN
# 328   NaN    NaN     NaN
# 331   NaN    NaN     NaN
#
# [149 rows x 28 columns]

# %%
#netprofit

# %%
a = pd.read_csv('value_scan.csv')

# %%
x=a.iloc[0:,1:]

# %%
x
# Out:
#        Name    No.          Links Sign    Last  Chg%      Volume  Value (k)  \
# 0       ACE   11.0      i | 1 | 3  NaN    3.92  0.00  93454200.0   365854.0
# 1       AEC   16.0      i | 1 | 3    C    7.85 -1.26   3129900.0    24535.0
# 2    AEONTS   17.0  i | 1 | 2 | 3  NaN  186.00 -1.33   1237400.0   231962.0
# 3       AIE   24.0  i | 1 | 2 | 3  NaN    1.33 -3.62  18802000.0    25246.0
# 4       ALL   31.0      i | 1 | 3  NaN    3.14  1.95  22535100.0    69730.0
# ..      ...    ...            ...  ...     ...   ...         ...        ...
# 144     VPO  738.0      i | 1 | 3  NaN    1.22 -3.17   4254600.0     5238.0
# 145   WHAUP  745.0  i | 1 | 2 | 3  NaN    4.28 -1.38   4389500.0    18954.0
# 146     WIN  748.0  i | 1 | 2 | 3  NaN    0.85  0.00  27581700.0    23456.0
# 147  WINMED  749.0              i  NaN    6.90  0.00  15266300.0   104544.0
# 148     YGG  758.0      i | 1 | 3  NaN   20.70 -1.43    481700.0     9971.0
#
#      MCap (M)     P/E  ... FFloat%  MG%  Magic1  Magic2    PEG  CG        rsi  \
# 0     39890.0   31.30  ...   22.62  NaN   600.0   555.0   0.37 NaN        NaN
# 1     11274.0     NaN  ...   25.59  NaN     NaN     NaN    NaN NaN        NaN
# 2     46500.0   10.79  ...   30.86  NaN   142.0   298.0   1.25 NaN        NaN
# 3      6959.0   14.90  ...   26.00  NaN   264.0   230.0  -0.10 NaN        NaN
# 4      2109.0   37.01  ...   27.52  NaN   891.0   833.0 -12.74 NaN        NaN
# ..        ...     ...  ...     ...  ...     ...     ...    ...  ..        ...
# 144    1147.0  339.16  ...   32.22  NaN  1066.0  1018.0 -21.88 NaN        NaN
# 145   16371.0   18.19  ...   25.59  NaN   578.0   605.0   0.19 NaN        NaN
# 146     477.0     NaN  ...   31.53  NaN     NaN     NaN    NaN NaN        NaN
# 147       0.0     NaN  ...   28.83  NaN     NaN     NaN    NaN NaN        NaN
# 148    3726.0   63.05  ...   26.32  NaN   627.0   555.0   3.86 NaN        NaN
#
#     Ema20  Ema50  Ema200
# 0     NaN    NaN     NaN
# 1     NaN    NaN     NaN
# 2     NaN    NaN     NaN
# 3     NaN    NaN     NaN
# 4     NaN    NaN     NaN
# ..    ...    ...     ...
# 144   NaN    NaN     NaN
# 145   NaN    NaN     NaN
# 146   NaN    NaN     NaN
# 147   NaN    NaN     NaN
# 148   NaN    NaN     NaN
#
# [149 rows x 28 columns]

# %%
number=x.shape[0]
number
# Out:
# 149

# %%
i=0
e=0
while e< number:
    y=x.iloc[i,16]
    if y > netprofit :
         i+=1
         e+=1
    else : 
         x = x.drop(e,axis=0)
         x.reset_index(drop=True) # Reset index
         e+=1   
print("finish")
# Out:
# finish

# %%
x.to_csv('netprofit_scan.csv')
x
# Out:
#        Name    No.          Links Sign    Last  Chg%      Volume  Value (k)  \
# 0       ACE   11.0      i | 1 | 3  NaN    3.92  0.00  93454200.0   365854.0
# 2    AEONTS   17.0  i | 1 | 2 | 3  NaN  186.00 -1.33   1237400.0   231962.0
# 3       AIE   24.0  i | 1 | 2 | 3  NaN    1.33 -3.62  18802000.0    25246.0
# 5      ALLA   32.0  i | 1 | 2 | 3  NaN    1.92 -2.54   3189000.0     6133.0
# 8      APCO   44.0  i | 1 | 2 | 3  NaN    6.35 -2.31   1026600.0     6567.0
# ..      ...    ...            ...  ...     ...   ...         ...        ...
# 142     VNG  736.0  i | 1 | 2 | 3  NaN    7.45 -3.87   2847900.0    21417.0
# 143     VNT  737.0      i | 1 | 3  NaN   37.50  0.00    803500.0    30146.0
# 145   WHAUP  745.0  i | 1 | 2 | 3  NaN    4.28 -1.38   4389500.0    18954.0
# 147  WINMED  749.0              i  NaN    6.90  0.00  15266300.0   104544.0
# 148     YGG  758.0      i | 1 | 3  NaN   20.70 -1.43    481700.0     9971.0
#
#      MCap (M)    P/E  ... FFloat%  MG% Magic1  Magic2    PEG  CG        rsi  \
# 0     39890.0  31.30  ...   22.62  NaN  600.0   555.0   0.37 NaN        NaN
# 2     46500.0  10.79  ...   30.86  NaN  142.0   298.0   1.25 NaN        NaN
# 3      6959.0  14.90  ...   26.00  NaN  264.0   230.0  -0.10 NaN        NaN
# 5      1152.0  31.30  ...   34.44  NaN  798.0   766.0  21.22 NaN        NaN
# 8      3810.0  61.43  ...   30.79  NaN  730.0   613.0 -17.53 NaN        NaN
# ..        ...    ...  ...     ...  ...    ...     ...    ...  ..        ...
# 142   12928.0    NaN  ...   22.19  NaN    NaN     NaN    NaN NaN        NaN
# 143   44445.0  15.98  ...   16.24  NaN  414.0   311.0   0.37 NaN        NaN
# 145   16371.0  18.19  ...   25.59  NaN  578.0   605.0   0.19 NaN        NaN
# 147       0.0    NaN  ...   28.83  NaN    NaN     NaN    NaN NaN        NaN
# 148    3726.0  63.05  ...   26.32  NaN  627.0   555.0   3.86 NaN        NaN
#
#     Ema20  Ema50  Ema200
# 0     NaN    NaN     NaN
# 2     NaN    NaN     NaN
# 3     NaN    NaN     NaN
# 5     NaN    NaN     NaN
# 8     NaN    NaN     NaN
# ..    ...    ...     ...
# 142   NaN    NaN     NaN
# 143   NaN    NaN     NaN
# 145   NaN    NaN     NaN
# 147   NaN    NaN     NaN
# 148   NaN    NaN     NaN
#
# [128 rows x 28 columns]

# %%
#check RSI

# %%
g=pd.read_csv('netprofit_scan.csv')#เลือกหุ้น
x=g.iloc[0:,1:]
x
# Out:
#        Name    No.          Links  Sign    Last  Chg%      Volume  Value (k)  \
# 0       ACE   11.0      i | 1 | 3   NaN    3.92  0.00  93454200.0   365854.0
# 1    AEONTS   17.0  i | 1 | 2 | 3   NaN  186.00 -1.33   1237400.0   231962.0
# 2       AIE   24.0  i | 1 | 2 | 3   NaN    1.33 -3.62  18802000.0    25246.0
# 3      ALLA   32.0  i | 1 | 2 | 3   NaN    1.92 -2.54   3189000.0     6133.0
# 4      APCO   44.0  i | 1 | 2 | 3   NaN    6.35 -2.31   1026600.0     6567.0
# ..      ...    ...            ...   ...     ...   ...         ...        ...
# 123     VNG  736.0  i | 1 | 2 | 3   NaN    7.45 -3.87   2847900.0    21417.0
# 124     VNT  737.0      i | 1 | 3   NaN   37.50  0.00    803500.0    30146.0
# 125   WHAUP  745.0  i | 1 | 2 | 3   NaN    4.28 -1.38   4389500.0    18954.0
# 126  WINMED  749.0              i   NaN    6.90  0.00  15266300.0   104544.0
# 127     YGG  758.0      i | 1 | 3   NaN   20.70 -1.43    481700.0     9971.0
#
#      MCap (M)    P/E  ... FFloat%  MG% Magic1  Magic2    PEG  CG        rsi  \
# 0     39890.0  31.30  ...   22.62  NaN  600.0   555.0   0.37 NaN        NaN
# 1     46500.0  10.79  ...   30.86  NaN  142.0   298.0   1.25 NaN        NaN
# 2      6959.0  14.90  ...   26.00  NaN  264.0   230.0  -0.10 NaN        NaN
# 3      1152.0  31.30  ...   34.44  NaN  798.0   766.0  21.22 NaN        NaN
# 4      3810.0  61.43  ...   30.79  NaN  730.0   613.0 -17.53 NaN        NaN
# ..        ...    ...  ...     ...  ...    ...     ...    ...  ..        ...
# 123   12928.0    NaN  ...   22.19  NaN    NaN     NaN    NaN NaN        NaN
# 124   44445.0  15.98  ...   16.24  NaN  414.0   311.0   0.37 NaN        NaN
# 125   16371.0  18.19  ...   25.59  NaN  578.0   605.0   0.19 NaN        NaN
# 126       0.0    NaN  ...   28.83  NaN    NaN     NaN    NaN NaN        NaN
# 127    3726.0  63.05  ...   26.32  NaN  627.0   555.0   3.86 NaN        NaN
#
#     Ema20  Ema50  Ema200
# 0     NaN    NaN     NaN
# 1     NaN    NaN     NaN
# 2     NaN    NaN     NaN
# 3     NaN    NaN     NaN
# 4     NaN    NaN     NaN
# ..    ...    ...     ...
# 123   NaN    NaN     NaN
# 124   NaN    NaN     NaN
# 125   NaN    NaN     NaN
# 126   NaN    NaN     NaN
# 127   NaN    NaN     NaN
#
# [128 rows x 28 columns]

# %%
a=x.iloc[0:,24]
a
# Out:
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
#        ..
# 123   NaN
# 124   NaN
# 125   NaN
# 126   NaN
# 127   NaN
# Name:       rsi, Length: 128, dtype: float64

# %%
number=x.shape[0]
y=x.iloc[0,0]
y
# Out:
# 'ACE'

# %%
i=0
e=0
while e <number:
 y=x.iloc[i,0]
 from datetime import datetime
 from datetime import timedelta
 now = datetime.today()
 duration= timedelta(days=300)
 start=now-duration
 s = yfinance.download(y+".BK",start,now)
 rsi = talib.RSI(s["Close"])
 print_rsi=rsi[-1]
 stock_rsi=print_rsi
 if stock_rsi>set_rsi:
   x.iloc[i,24]=stock_rsi
   i+=1
   e+=1
 else  : 
   x = x.drop(e,axis=0)
   x.reset_index(drop=True) # Reset index
   e+=1
print("finish")
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# finish

# %%
x.to_csv('rsi_scan.csv')
x
# Out:
#        Name    No.          Links  Sign    Last  Chg%       Volume  Value (k)  \
# 0       ACE   11.0      i | 1 | 3   NaN    3.92  0.00   93454200.0   365854.0
# 4      APCO   44.0  i | 1 | 2 | 3   NaN    6.35 -2.31    1026600.0     6567.0
# 5     APURE   48.0  i | 1 | 2 | 3   NaN    6.20  9.73  138523700.0   869819.0
# 6      ARIP   52.0  i | 1 | 2 | 3   NaN    1.03  0.98   18361100.0    18393.0
# 13      BGC   87.0      i | 1 | 3   NaN   11.50 -2.54    9710100.0   110476.0
# 14      BIZ   92.0  i | 1 | 2 | 3   NaN    9.60 -2.04    2671000.0    25625.0
# 18      CBG  115.0  i | 1 | 2 | 3   NaN  151.50  0.00    4514900.0   681010.0
# 21      CKP  135.0  i | 1 | 2 | 3   NaN    5.90  0.00   71950200.0   431845.0
# 32     DTAC  177.0  i | 1 | 2 | 3   NaN   31.75  2.42   17459200.0   551269.0
# 35      EPG  193.0  i | 1 | 2 | 3   NaN   13.00  0.78   45757400.0   595634.0
# 41   GLOBAL  225.0  i | 1 | 2 | 3   NaN   23.80 -1.24    9738600.0   231378.0
# 42     GPSC  228.0  i | 1 | 2 | 3   NaN   79.75 -0.62   21824900.0  1737063.0
# 55    LANNA  319.0  i | 1 | 2 | 3   NaN   18.40  0.55    3943900.0    72541.0
# 60      MSC  371.0      i | 1 | 3   NaN    6.40 -0.78    1739800.0    11409.0
# 61      MTC  372.0  i | 1 | 2 | 3   NaN   63.25 -1.17    6956600.0   438791.0
# 63      NDR  381.0  i | 1 | 2 | 3   NaN    3.38 -3.98   12458000.0    42588.0
# 76      RWI  493.0      i | 1 | 3   NaN    2.04 -2.86   40685500.0    84860.0
# 85     SCGP  518.0      i | 1 | 3   NaN   64.00 -0.39    5839600.0   373367.0
# 95    SONIC  565.0      i | 1 | 3   NaN    5.00  0.00   45384900.0   230170.0
# 96    SPACK  568.0  i | 1 | 2 | 3   NaN    3.52 -1.12   12914300.0    46517.0
# 112   TPLAS  676.0      i | 1 | 3   NaN    5.00 -2.91   16328300.0    83010.0
# 121     VIH  734.0  i | 1 | 2 | 3   NaN   12.90 -3.73    3461900.0    44662.0
# 126  WINMED  749.0              i   NaN    6.90  0.00   15266300.0   104544.0
#
#      MCap (M)     P/E  ... FFloat%  MG%  Magic1  Magic2    PEG  CG        rsi  \
# 0     39890.0   31.30  ...   22.62  NaN   600.0   555.0   0.37 NaN  58.659763
# 4      3810.0   61.43  ...   30.79  NaN   730.0   613.0 -17.53 NaN  69.212148
# 5      5941.0   19.25  ...   26.92  NaN   385.0   318.0   0.10 NaN  84.371076
# 6       480.0  135.53  ...   28.67  NaN  1027.0  1036.0  10.89 NaN  62.689742
# 13     7986.0   14.85  ...   27.41  NaN   440.0   579.0   7.33 NaN  62.269328
# 14     3840.0   34.63  ...   24.41  NaN   492.0   625.0   8.41 NaN  61.785062
# 18   151500.0   44.24  ...   28.85  NaN   449.0   445.0   1.45 NaN  64.003630
# 21    47963.0   55.85  ...   24.22  NaN   922.0   936.0   0.78 NaN  60.730234
# 32    75178.0   18.48  ...   29.26  NaN   329.0   627.0  -0.15 NaN  61.642585
# 35    36400.0   29.86  ...   25.90  NaN   578.0   541.0  -7.51 NaN  67.128540
# 41   109520.0   47.50  ...   32.11  NaN   623.0   653.0   2.38 NaN  61.156509
# 42   224873.0   28.46  ...   24.75  NaN   663.0   680.0   0.83 NaN  64.816229
# 55     9660.0   27.54  ...   24.48  NaN   665.0   537.0   1.76 NaN  68.623417
# 60     2304.0   14.73  ...   30.98  NaN   494.0   528.0  -4.98 NaN  61.037828
# 61   134090.0   25.06  ...   32.12  NaN   355.0   440.0   0.54 NaN  63.582016
# 63     1141.0   19.53  ...   23.09  NaN   572.0   506.0  -0.22 NaN  61.725771
# 76     1298.0    5.97  ...   20.01  NaN    64.0    28.0  -0.06 NaN  63.918589
# 85   274747.0   40.05  ...   26.21  NaN   736.0   728.0    NaN NaN  66.273571
# 95     2750.0   31.51  ...   31.66  NaN   547.0   483.0   2.22 NaN  64.111046
# 96     1056.0   12.45  ...   24.28  NaN   267.0   348.0   0.05 NaN  61.298258
# 112    1350.0   35.21  ...   25.73  NaN   598.0   496.0   1.61 NaN  65.569703
# 121    7362.0   36.34  ...   29.03  NaN   559.0   526.0   2.27 NaN  59.773859
# 126       0.0     NaN  ...   28.83  NaN     NaN     NaN    NaN NaN  61.171617
#
#     Ema20  Ema50  Ema200
# 0     NaN    NaN     NaN
# 4     NaN    NaN     NaN
# 5     NaN    NaN     NaN
# 6     NaN    NaN     NaN
# 13    NaN    NaN     NaN
# 14    NaN    NaN     NaN
# 18    NaN    NaN     NaN
# 21    NaN    NaN     NaN
# 32    NaN    NaN     NaN
# 35    NaN    NaN     NaN
# 41    NaN    NaN     NaN
# 42    NaN    NaN     NaN
# 55    NaN    NaN     NaN
# 60    NaN    NaN     NaN
# 61    NaN    NaN     NaN
# 63    NaN    NaN     NaN
# 76    NaN    NaN     NaN
# 85    NaN    NaN     NaN
# 95    NaN    NaN     NaN
# 96    NaN    NaN     NaN
# 112   NaN    NaN     NaN
# 121   NaN    NaN     NaN
# 126   NaN    NaN     NaN
#
# [23 rows x 28 columns]

# %%
#filter code

# %%
#Ema

# %%
a=pd.read_csv('rsi_scan.csv')#เลือกหุ้น
x=a.iloc[0:,1:]
x
# Out:
#       Name    No.          Links  Sign    Last  Chg%       Volume  Value (k)  \
# 0      ACE   11.0      i | 1 | 3   NaN    3.92  0.00   93454200.0   365854.0
# 1     APCO   44.0  i | 1 | 2 | 3   NaN    6.35 -2.31    1026600.0     6567.0
# 2    APURE   48.0  i | 1 | 2 | 3   NaN    6.20  9.73  138523700.0   869819.0
# 3     ARIP   52.0  i | 1 | 2 | 3   NaN    1.03  0.98   18361100.0    18393.0
# 4      BGC   87.0      i | 1 | 3   NaN   11.50 -2.54    9710100.0   110476.0
# 5      BIZ   92.0  i | 1 | 2 | 3   NaN    9.60 -2.04    2671000.0    25625.0
# 6      CBG  115.0  i | 1 | 2 | 3   NaN  151.50  0.00    4514900.0   681010.0
# 7      CKP  135.0  i | 1 | 2 | 3   NaN    5.90  0.00   71950200.0   431845.0
# 8     DTAC  177.0  i | 1 | 2 | 3   NaN   31.75  2.42   17459200.0   551269.0
# 9      EPG  193.0  i | 1 | 2 | 3   NaN   13.00  0.78   45757400.0   595634.0
# 10  GLOBAL  225.0  i | 1 | 2 | 3   NaN   23.80 -1.24    9738600.0   231378.0
# 11    GPSC  228.0  i | 1 | 2 | 3   NaN   79.75 -0.62   21824900.0  1737063.0
# 12   LANNA  319.0  i | 1 | 2 | 3   NaN   18.40  0.55    3943900.0    72541.0
# 13     MSC  371.0      i | 1 | 3   NaN    6.40 -0.78    1739800.0    11409.0
# 14     MTC  372.0  i | 1 | 2 | 3   NaN   63.25 -1.17    6956600.0   438791.0
# 15     NDR  381.0  i | 1 | 2 | 3   NaN    3.38 -3.98   12458000.0    42588.0
# 16     RWI  493.0      i | 1 | 3   NaN    2.04 -2.86   40685500.0    84860.0
# 17    SCGP  518.0      i | 1 | 3   NaN   64.00 -0.39    5839600.0   373367.0
# 18   SONIC  565.0      i | 1 | 3   NaN    5.00  0.00   45384900.0   230170.0
# 19   SPACK  568.0  i | 1 | 2 | 3   NaN    3.52 -1.12   12914300.0    46517.0
# 20   TPLAS  676.0      i | 1 | 3   NaN    5.00 -2.91   16328300.0    83010.0
# 21     VIH  734.0  i | 1 | 2 | 3   NaN   12.90 -3.73    3461900.0    44662.0
# 22  WINMED  749.0              i   NaN    6.90  0.00   15266300.0   104544.0
#
#     MCap (M)     P/E  ... FFloat%  MG%  Magic1  Magic2    PEG  CG        rsi  \
# 0    39890.0   31.30  ...   22.62  NaN   600.0   555.0   0.37 NaN  58.659763
# 1     3810.0   61.43  ...   30.79  NaN   730.0   613.0 -17.53 NaN  69.212148
# 2     5941.0   19.25  ...   26.92  NaN   385.0   318.0   0.10 NaN  84.371076
# 3      480.0  135.53  ...   28.67  NaN  1027.0  1036.0  10.89 NaN  62.689742
# 4     7986.0   14.85  ...   27.41  NaN   440.0   579.0   7.33 NaN  62.269328
# 5     3840.0   34.63  ...   24.41  NaN   492.0   625.0   8.41 NaN  61.785062
# 6   151500.0   44.24  ...   28.85  NaN   449.0   445.0   1.45 NaN  64.003630
# 7    47963.0   55.85  ...   24.22  NaN   922.0   936.0   0.78 NaN  60.730234
# 8    75178.0   18.48  ...   29.26  NaN   329.0   627.0  -0.15 NaN  61.642585
# 9    36400.0   29.86  ...   25.90  NaN   578.0   541.0  -7.51 NaN  67.128540
# 10  109520.0   47.50  ...   32.11  NaN   623.0   653.0   2.38 NaN  61.156509
# 11  224873.0   28.46  ...   24.75  NaN   663.0   680.0   0.83 NaN  64.816229
# 12    9660.0   27.54  ...   24.48  NaN   665.0   537.0   1.76 NaN  68.623417
# 13    2304.0   14.73  ...   30.98  NaN   494.0   528.0  -4.98 NaN  61.037828
# 14  134090.0   25.06  ...   32.12  NaN   355.0   440.0   0.54 NaN  63.582016
# 15    1141.0   19.53  ...   23.09  NaN   572.0   506.0  -0.22 NaN  61.725771
# 16    1298.0    5.97  ...   20.01  NaN    64.0    28.0  -0.06 NaN  63.918589
# 17  274747.0   40.05  ...   26.21  NaN   736.0   728.0    NaN NaN  66.273571
# 18    2750.0   31.51  ...   31.66  NaN   547.0   483.0   2.22 NaN  64.111046
# 19    1056.0   12.45  ...   24.28  NaN   267.0   348.0   0.05 NaN  61.298258
# 20    1350.0   35.21  ...   25.73  NaN   598.0   496.0   1.61 NaN  65.569703
# 21    7362.0   36.34  ...   29.03  NaN   559.0   526.0   2.27 NaN  59.773859
# 22       0.0     NaN  ...   28.83  NaN     NaN     NaN    NaN NaN  61.171617
#
#    Ema20  Ema50  Ema200
# 0    NaN    NaN     NaN
# 1    NaN    NaN     NaN
# 2    NaN    NaN     NaN
# 3    NaN    NaN     NaN
# 4    NaN    NaN     NaN
# 5    NaN    NaN     NaN
# 6    NaN    NaN     NaN
# 7    NaN    NaN     NaN
# 8    NaN    NaN     NaN
# 9    NaN    NaN     NaN
# 10   NaN    NaN     NaN
# 11   NaN    NaN     NaN
# 12   NaN    NaN     NaN
# 13   NaN    NaN     NaN
# 14   NaN    NaN     NaN
# 15   NaN    NaN     NaN
# 16   NaN    NaN     NaN
# 17   NaN    NaN     NaN
# 18   NaN    NaN     NaN
# 19   NaN    NaN     NaN
# 20   NaN    NaN     NaN
# 21   NaN    NaN     NaN
# 22   NaN    NaN     NaN
#
# [23 rows x 28 columns]

# %%
stock_ema=x.iloc[0:,25] #first stock in ema
stock_ema
# Out:
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# 5    NaN
# 6    NaN
# 7    NaN
# 8    NaN
# 9    NaN
# 10   NaN
# 11   NaN
# 12   NaN
# 13   NaN
# 14   NaN
# 15   NaN
# 16   NaN
# 17   NaN
# 18   NaN
# 19   NaN
# 20   NaN
# 21   NaN
# 22   NaN
# Name: Ema20, dtype: float64

# %%
#เทสEMA

# %%
 number=x.shape[0]
 y=x.iloc[0,0]
y
# Out:
# 'ACE'

# %%
i=0
e=0
while e <number:
  y=x.iloc[i,0]
  end = datetime.today()
  duration= timedelta(days=365)
  start=end-duration
  s = web.DataReader(y+".BK", 'yahoo', start, end)
  close_array=s.iloc[0:,3:-2]
  close_array['EMA'] = talib.EMA(close_array['Close'], timeperiod =set_ema0)
  close_data = close_array.iloc[-1,0]
  ema_data0 =close_array.iloc[-1,1]
  stock_ema0 = ema_data0
  close_array['EMA'] = talib.EMA(close_array['Close'], timeperiod =set_ema1)
  ema_data1 =close_array.iloc[-1,1]
  stock_ema1 = ema_data1
  close_array['EMA'] = talib.EMA(close_array['Close'], timeperiod =set_ema2)
  ema_data2 =close_array.iloc[-1,1]
  stock_ema2 = ema_data2
  if close_data > stock_ema0 and close_data > stock_ema1 and close_data > stock_ema2 :
   x.iloc[i,25]=stock_ema0
   x.iloc[i,26]=stock_ema1
   x.iloc[i,27]=stock_ema2
   i+=1
   e+=1
  else  : 
   x = x.drop(e,axis=0)
   x.reset_index(drop=True) # Reset index
   e+=1
print("finish")
# Out:
# finish

# %%
x.to_csv('finish_scan.csv')
x
# Out:
#       Name    No.          Links  Sign    Last  Chg%       Volume  Value (k)  \
# 0      ACE   11.0      i | 1 | 3   NaN    3.92  0.00   93454200.0   365854.0
# 1     APCO   44.0  i | 1 | 2 | 3   NaN    6.35 -2.31    1026600.0     6567.0
# 2    APURE   48.0  i | 1 | 2 | 3   NaN    6.20  9.73  138523700.0   869819.0
# 3     ARIP   52.0  i | 1 | 2 | 3   NaN    1.03  0.98   18361100.0    18393.0
# 4      BGC   87.0      i | 1 | 3   NaN   11.50 -2.54    9710100.0   110476.0
# 5      BIZ   92.0  i | 1 | 2 | 3   NaN    9.60 -2.04    2671000.0    25625.0
# 6      CBG  115.0  i | 1 | 2 | 3   NaN  151.50  0.00    4514900.0   681010.0
# 7      CKP  135.0  i | 1 | 2 | 3   NaN    5.90  0.00   71950200.0   431845.0
# 9      EPG  193.0  i | 1 | 2 | 3   NaN   13.00  0.78   45757400.0   595634.0
# 10  GLOBAL  225.0  i | 1 | 2 | 3   NaN   23.80 -1.24    9738600.0   231378.0
# 11    GPSC  228.0  i | 1 | 2 | 3   NaN   79.75 -0.62   21824900.0  1737063.0
# 12   LANNA  319.0  i | 1 | 2 | 3   NaN   18.40  0.55    3943900.0    72541.0
# 13     MSC  371.0      i | 1 | 3   NaN    6.40 -0.78    1739800.0    11409.0
# 14     MTC  372.0  i | 1 | 2 | 3   NaN   63.25 -1.17    6956600.0   438791.0
# 15     NDR  381.0  i | 1 | 2 | 3   NaN    3.38 -3.98   12458000.0    42588.0
# 16     RWI  493.0      i | 1 | 3   NaN    2.04 -2.86   40685500.0    84860.0
# 18   SONIC  565.0      i | 1 | 3   NaN    5.00  0.00   45384900.0   230170.0
# 19   SPACK  568.0  i | 1 | 2 | 3   NaN    3.52 -1.12   12914300.0    46517.0
# 20   TPLAS  676.0      i | 1 | 3   NaN    5.00 -2.91   16328300.0    83010.0
# 21     VIH  734.0  i | 1 | 2 | 3   NaN   12.90 -3.73    3461900.0    44662.0
#
#     MCap (M)     P/E  ... FFloat%  MG%  Magic1  Magic2    PEG  CG        rsi  \
# 0    39890.0   31.30  ...   22.62  NaN   600.0   555.0   0.37 NaN  58.659763
# 1     3810.0   61.43  ...   30.79  NaN   730.0   613.0 -17.53 NaN  69.212148
# 2     5941.0   19.25  ...   26.92  NaN   385.0   318.0   0.10 NaN  84.371076
# 3      480.0  135.53  ...   28.67  NaN  1027.0  1036.0  10.89 NaN  62.689742
# 4     7986.0   14.85  ...   27.41  NaN   440.0   579.0   7.33 NaN  62.269328
# 5     3840.0   34.63  ...   24.41  NaN   492.0   625.0   8.41 NaN  61.785062
# 6   151500.0   44.24  ...   28.85  NaN   449.0   445.0   1.45 NaN  64.003630
# 7    47963.0   55.85  ...   24.22  NaN   922.0   936.0   0.78 NaN  60.730234
# 9    36400.0   29.86  ...   25.90  NaN   578.0   541.0  -7.51 NaN  67.128540
# 10  109520.0   47.50  ...   32.11  NaN   623.0   653.0   2.38 NaN  61.156509
# 11  224873.0   28.46  ...   24.75  NaN   663.0   680.0   0.83 NaN  64.816229
# 12    9660.0   27.54  ...   24.48  NaN   665.0   537.0   1.76 NaN  68.623417
# 13    2304.0   14.73  ...   30.98  NaN   494.0   528.0  -4.98 NaN  61.037828
# 14  134090.0   25.06  ...   32.12  NaN   355.0   440.0   0.54 NaN  63.582016
# 15    1141.0   19.53  ...   23.09  NaN   572.0   506.0  -0.22 NaN  61.725771
# 16    1298.0    5.97  ...   20.01  NaN    64.0    28.0  -0.06 NaN  63.918589
# 18    2750.0   31.51  ...   31.66  NaN   547.0   483.0   2.22 NaN  64.111046
# 19    1056.0   12.45  ...   24.28  NaN   267.0   348.0   0.05 NaN  61.298258
# 20    1350.0   35.21  ...   25.73  NaN   598.0   496.0   1.61 NaN  65.569703
# 21    7362.0   36.34  ...   29.03  NaN   559.0   526.0   2.27 NaN  59.773859
#
#          Ema20       Ema50      Ema200
# 0     3.812066    3.752089    3.558392
# 1     5.711998    4.898045    4.105816
# 2     4.727234    4.497702    3.290091
# 3     0.924729    0.824721    0.606812
# 4    11.090093   10.628328   10.531498
# 5     9.030577    7.662583    5.160224
# 6   146.784891  139.065159  129.159344
# 7     5.657673    5.508907    5.173738
# 9    12.155956   11.620288    8.754832
# 10   23.104508   22.357753   20.015253
# 11   76.225277   74.858205   71.637843
# 12   16.591685   14.644301   10.060059
# 13    6.265712    6.230865    6.146313
# 14   60.491319   60.879298   59.260771
# 15    3.108367    2.946130    2.136177
# 16    1.830889    1.739566    1.493461
# 18    4.692128    4.270633    2.732294
# 19    3.289538    3.147343    2.812946
# 20    4.361446    3.484271    2.269908
# 21   12.485762   11.022639    8.517428
#
# [20 rows x 28 columns]

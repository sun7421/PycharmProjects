# %%
import numpy as np#จัดการตัวเลขarray
import pandas as pd
import yfinance
from matplotlib import pyplot as plt
import talib
import pandas_datareader as web
import datetime
from datetime import datetime
from datetime import timedelta

# %%
x = pd.read_excel('stocksun.xlsm')

# %%
freefloat = 30
valuek = 5000
netprofit=0
set_ema0=20
set_ema1=50
set_ema2=200
set_rsi=58

# %%
#check freefloat

# %%
number=x.shape[0]
number
# Out:
# 762

# %%
i=0
e=0
while e< number:
    y=x.iloc[i,18]
    if y<=freefloat :
         i+=1
         e+=1
    else : 
         x = x.drop(e,axis=0)
         x.reset_index(drop=True) # Reset index
         e+=1   
print("finish")
# Out:
# finish

# %%
x.to_csv('freefloat_scan.csv')
x
# Out:
#        Name    No.          Links  Sign   Last  Chg%      Volume  Value (k)  \
# 2    3K-BAT    2.0              i   NaN  67.50  0.00         0.0        0.0
# 4         A    4.0  i | 1 | 2 | 3   NaN   4.98  0.00      2500.0       12.0
# 5        A5    5.0      i | 1 | 3  SPNC   1.50  0.00         0.0        0.0
# 7     ABICO    7.0  i | 1 | 2 | 3   NaN   5.15 -1.90     56100.0      286.0
# 11      ACE   11.0      i | 1 | 3   NaN   3.92  0.00  93454200.0   365854.0
# ..      ...    ...            ...   ...    ...   ...         ...        ...
# 753     WPH  753.0  i | 1 | 2 | 3   NaN   2.14 -6.96   1332000.0     2923.0
# 754      WR  754.0      i | 1 | 3   NaN   0.35  0.00         0.0        0.0
# 758     YGG  758.0      i | 1 | 3   NaN  20.70 -1.43    481700.0     9971.0
# 759   YUASA  759.0      i | 1 | 3   NaN  17.30 -1.70     95800.0     1663.0
# 760     ZEN  760.0      i | 1 | 3   NaN  11.50 -1.71     92600.0     1060.0
#
#      MCap (M)     P/E  ... FFloat%  MG%  Magic1  Magic2   PEG  CG        rsi  \
# 2      5292.0  198.86  ...    2.10  NaN   999.0     NaN   NaN NaN        NaN
# 4      4880.0   30.79  ...   25.86  NaN   784.0   779.0 -0.12 NaN        NaN
# 5      1685.0     NaN  ...   20.60  NaN     NaN     NaN   NaN NaN        NaN
# 7      1259.0   28.48  ...   27.66  NaN   765.0   760.0 -0.27 NaN        NaN
# 11    39890.0   31.30  ...   22.62  NaN   600.0   555.0  0.37 NaN        NaN
# ..        ...     ...  ...     ...  ...     ...     ...   ...  ..        ...
# 753    1284.0     NaN  ...   29.57  NaN     NaN     NaN   NaN NaN        NaN
# 754     872.0     NaN  ...    2.96  NaN     NaN     NaN   NaN NaN        NaN
# 758    3726.0   63.05  ...   26.32  NaN   627.0   555.0  3.86 NaN        NaN
# 759    1862.0   11.53  ...   15.27  NaN   225.0   177.0  0.30 NaN        NaN
# 760    3450.0  381.98  ...   26.68  NaN  1068.0  1081.0 -4.15 NaN        NaN
#
#     Ema20  Ema50  Ema200
# 2     NaN    NaN     NaN
# 4     NaN    NaN     NaN
# 5     NaN    NaN     NaN
# 7     NaN    NaN     NaN
# 11    NaN    NaN     NaN
# ..    ...    ...     ...
# 753   NaN    NaN     NaN
# 754   NaN    NaN     NaN
# 758   NaN    NaN     NaN
# 759   NaN    NaN     NaN
# 760   NaN    NaN     NaN
#
# [241 rows x 28 columns]

# %%
#check value(k)

# %%
a=pd.read_csv('freefloat_scan.csv')
x=a.iloc[0:,1:]

# %%
number=x.shape[0]
number
# Out:
# 241

# %%
 y=x.iloc[0,7]
y
# Out:
# 0.0

# %%
i=0
e=0
while e< number:
    y=x.iloc[i,7]
    if y > valuek :
         i+=1
         e+=1
    else : 
         x = x.drop(e,axis=0)
         x.reset_index(drop=True) # Reset index
         e+=1   
print("finish")
# Out:
# finish

# %%
x.to_csv('value_scan.csv')
x
# Out:
#        Name    No.          Links Sign   Last  Chg%      Volume  Value (k)  \
# 4       ACE   11.0      i | 1 | 3  NaN   3.92  0.00  93454200.0   365854.0
# 6       AEC   16.0      i | 1 | 3    C   7.85 -1.26   3129900.0    24535.0
# 8       AIE   24.0  i | 1 | 2 | 3  NaN   1.33 -3.62  18802000.0    25246.0
# 10      ALL   31.0      i | 1 | 3  NaN   3.14  1.95  22535100.0    69730.0
# 11      ALT   33.0      i | 1 | 3  NaN   2.88 -4.00  13915000.0    40886.0
# ..      ...    ...            ...  ...    ...   ...         ...        ...
# 230     VNG  736.0  i | 1 | 2 | 3  NaN   7.45 -3.87   2847900.0    21417.0
# 231     VNT  737.0      i | 1 | 3  NaN  37.50  0.00    803500.0    30146.0
# 234   WHAUP  745.0  i | 1 | 2 | 3  NaN   4.28 -1.38   4389500.0    18954.0
# 235  WINMED  749.0              i  NaN   6.90  0.00  15266300.0   104544.0
# 238     YGG  758.0      i | 1 | 3  NaN  20.70 -1.43    481700.0     9971.0
#
#      MCap (M)    P/E  ... FFloat%  MG% Magic1  Magic2    PEG  CG        rsi  \
# 4     39890.0  31.30  ...   22.62  NaN  600.0   555.0   0.37 NaN        NaN
# 6     11274.0    NaN  ...   25.59  NaN    NaN     NaN    NaN NaN        NaN
# 8      6959.0  14.90  ...   26.00  NaN  264.0   230.0  -0.10 NaN        NaN
# 10     2109.0  37.01  ...   27.52  NaN  891.0   833.0 -12.74 NaN        NaN
# 11     3261.0  69.84  ...   29.63  NaN  980.0   925.0  -0.27 NaN        NaN
# ..        ...    ...  ...     ...  ...    ...     ...    ...  ..        ...
# 230   12928.0    NaN  ...   22.19  NaN    NaN     NaN    NaN NaN        NaN
# 231   44445.0  15.98  ...   16.24  NaN  414.0   311.0   0.37 NaN        NaN
# 234   16371.0  18.19  ...   25.59  NaN  578.0   605.0   0.19 NaN        NaN
# 235       0.0    NaN  ...   28.83  NaN    NaN     NaN    NaN NaN        NaN
# 238    3726.0  63.05  ...   26.32  NaN  627.0   555.0   3.86 NaN        NaN
#
#     Ema20  Ema50  Ema200
# 4     NaN    NaN     NaN
# 6     NaN    NaN     NaN
# 8     NaN    NaN     NaN
# 10    NaN    NaN     NaN
# 11    NaN    NaN     NaN
# ..    ...    ...     ...
# 230   NaN    NaN     NaN
# 231   NaN    NaN     NaN
# 234   NaN    NaN     NaN
# 235   NaN    NaN     NaN
# 238   NaN    NaN     NaN
#
# [92 rows x 28 columns]

# %%
#netprofit

# %%
a = pd.read_csv('value_scan.csv')

# %%
x=a.iloc[0:,1:]

# %%
x
# Out:
#       Name    No.          Links Sign   Last  Chg%      Volume  Value (k)  \
# 0      ACE   11.0      i | 1 | 3  NaN   3.92  0.00  93454200.0   365854.0
# 1      AEC   16.0      i | 1 | 3    C   7.85 -1.26   3129900.0    24535.0
# 2      AIE   24.0  i | 1 | 2 | 3  NaN   1.33 -3.62  18802000.0    25246.0
# 3      ALL   31.0      i | 1 | 3  NaN   3.14  1.95  22535100.0    69730.0
# 4      ALT   33.0      i | 1 | 3  NaN   2.88 -4.00  13915000.0    40886.0
# ..     ...    ...            ...  ...    ...   ...         ...        ...
# 87     VNG  736.0  i | 1 | 2 | 3  NaN   7.45 -3.87   2847900.0    21417.0
# 88     VNT  737.0      i | 1 | 3  NaN  37.50  0.00    803500.0    30146.0
# 89   WHAUP  745.0  i | 1 | 2 | 3  NaN   4.28 -1.38   4389500.0    18954.0
# 90  WINMED  749.0              i  NaN   6.90  0.00  15266300.0   104544.0
# 91     YGG  758.0      i | 1 | 3  NaN  20.70 -1.43    481700.0     9971.0
#
#     MCap (M)    P/E  ... FFloat%  MG% Magic1  Magic2    PEG  CG        rsi  \
# 0    39890.0  31.30  ...   22.62  NaN  600.0   555.0   0.37 NaN        NaN
# 1    11274.0    NaN  ...   25.59  NaN    NaN     NaN    NaN NaN        NaN
# 2     6959.0  14.90  ...   26.00  NaN  264.0   230.0  -0.10 NaN        NaN
# 3     2109.0  37.01  ...   27.52  NaN  891.0   833.0 -12.74 NaN        NaN
# 4     3261.0  69.84  ...   29.63  NaN  980.0   925.0  -0.27 NaN        NaN
# ..       ...    ...  ...     ...  ...    ...     ...    ...  ..        ...
# 87   12928.0    NaN  ...   22.19  NaN    NaN     NaN    NaN NaN        NaN
# 88   44445.0  15.98  ...   16.24  NaN  414.0   311.0   0.37 NaN        NaN
# 89   16371.0  18.19  ...   25.59  NaN  578.0   605.0   0.19 NaN        NaN
# 90       0.0    NaN  ...   28.83  NaN    NaN     NaN    NaN NaN        NaN
# 91    3726.0  63.05  ...   26.32  NaN  627.0   555.0   3.86 NaN        NaN
#
#    Ema20  Ema50  Ema200
# 0    NaN    NaN     NaN
# 1    NaN    NaN     NaN
# 2    NaN    NaN     NaN
# 3    NaN    NaN     NaN
# 4    NaN    NaN     NaN
# ..   ...    ...     ...
# 87   NaN    NaN     NaN
# 88   NaN    NaN     NaN
# 89   NaN    NaN     NaN
# 90   NaN    NaN     NaN
# 91   NaN    NaN     NaN
#
# [92 rows x 28 columns]

# %%
number=x.shape[0]
number
# Out:
# 92

# %%
i=0
e=0
while e< number:
    y=x.iloc[i,16]
    if y > netprofit :
         i+=1
         e+=1
    else : 
         x = x.drop(e,axis=0)
         x.reset_index(drop=True) # Reset index
         e+=1   
print("finish")
# Out:
# finish

# %%
x.to_csv('netprofit_scan.csv')
x
# Out:
#       Name    No.          Links Sign   Last  Chg%       Volume  Value (k)  \
# 0      ACE   11.0      i | 1 | 3  NaN   3.92  0.00   93454200.0   365854.0
# 2      AIE   24.0  i | 1 | 2 | 3  NaN   1.33 -3.62   18802000.0    25246.0
# 6    APURE   48.0  i | 1 | 2 | 3  NaN   6.20  9.73  138523700.0   869819.0
# 8     ARIP   52.0  i | 1 | 2 | 3  NaN   1.03  0.98   18361100.0    18393.0
# 10    AUCT   66.0  i | 1 | 2 | 3  NaN   9.85 -1.50    2028700.0    20051.0
# ..     ...    ...            ...  ...    ...   ...          ...        ...
# 87     VNG  736.0  i | 1 | 2 | 3  NaN   7.45 -3.87    2847900.0    21417.0
# 88     VNT  737.0      i | 1 | 3  NaN  37.50  0.00     803500.0    30146.0
# 89   WHAUP  745.0  i | 1 | 2 | 3  NaN   4.28 -1.38    4389500.0    18954.0
# 90  WINMED  749.0              i  NaN   6.90  0.00   15266300.0   104544.0
# 91     YGG  758.0      i | 1 | 3  NaN  20.70 -1.43     481700.0     9971.0
#
#     MCap (M)     P/E  ... FFloat%  MG%  Magic1  Magic2    PEG  CG        rsi  \
# 0    39890.0   31.30  ...   22.62  NaN   600.0   555.0   0.37 NaN        NaN
# 2     6959.0   14.90  ...   26.00  NaN   264.0   230.0  -0.10 NaN        NaN
# 6     5941.0   19.25  ...   26.92  NaN   385.0   318.0   0.10 NaN        NaN
# 8      480.0  135.53  ...   28.67  NaN  1027.0  1036.0  10.89 NaN        NaN
# 10    5418.0   22.10  ...   28.77  NaN   288.0   322.0   2.28 NaN        NaN
# ..       ...     ...  ...     ...  ...     ...     ...    ...  ..        ...
# 87   12928.0     NaN  ...   22.19  NaN     NaN     NaN    NaN NaN        NaN
# 88   44445.0   15.98  ...   16.24  NaN   414.0   311.0   0.37 NaN        NaN
# 89   16371.0   18.19  ...   25.59  NaN   578.0   605.0   0.19 NaN        NaN
# 90       0.0     NaN  ...   28.83  NaN     NaN     NaN    NaN NaN        NaN
# 91    3726.0   63.05  ...   26.32  NaN   627.0   555.0   3.86 NaN        NaN
#
#    Ema20  Ema50  Ema200
# 0    NaN    NaN     NaN
# 2    NaN    NaN     NaN
# 6    NaN    NaN     NaN
# 8    NaN    NaN     NaN
# 10   NaN    NaN     NaN
# ..   ...    ...     ...
# 87   NaN    NaN     NaN
# 88   NaN    NaN     NaN
# 89   NaN    NaN     NaN
# 90   NaN    NaN     NaN
# 91   NaN    NaN     NaN
#
# [79 rows x 28 columns]

# %%
#check RSI

# %%
g=pd.read_csv('netprofit_scan.csv')#เลือกหุ้น
x=g.iloc[0:,1:]
x
# Out:
#       Name    No.          Links  Sign   Last  Chg%       Volume  Value (k)  \
# 0      ACE   11.0      i | 1 | 3   NaN   3.92  0.00   93454200.0   365854.0
# 1      AIE   24.0  i | 1 | 2 | 3   NaN   1.33 -3.62   18802000.0    25246.0
# 2    APURE   48.0  i | 1 | 2 | 3   NaN   6.20  9.73  138523700.0   869819.0
# 3     ARIP   52.0  i | 1 | 2 | 3   NaN   1.03  0.98   18361100.0    18393.0
# 4     AUCT   66.0  i | 1 | 2 | 3   NaN   9.85 -1.50    2028700.0    20051.0
# ..     ...    ...            ...   ...    ...   ...          ...        ...
# 74     VNG  736.0  i | 1 | 2 | 3   NaN   7.45 -3.87    2847900.0    21417.0
# 75     VNT  737.0      i | 1 | 3   NaN  37.50  0.00     803500.0    30146.0
# 76   WHAUP  745.0  i | 1 | 2 | 3   NaN   4.28 -1.38    4389500.0    18954.0
# 77  WINMED  749.0              i   NaN   6.90  0.00   15266300.0   104544.0
# 78     YGG  758.0      i | 1 | 3   NaN  20.70 -1.43     481700.0     9971.0
#
#     MCap (M)     P/E  ... FFloat%  MG%  Magic1  Magic2    PEG  CG        rsi  \
# 0    39890.0   31.30  ...   22.62  NaN   600.0   555.0   0.37 NaN        NaN
# 1     6959.0   14.90  ...   26.00  NaN   264.0   230.0  -0.10 NaN        NaN
# 2     5941.0   19.25  ...   26.92  NaN   385.0   318.0   0.10 NaN        NaN
# 3      480.0  135.53  ...   28.67  NaN  1027.0  1036.0  10.89 NaN        NaN
# 4     5418.0   22.10  ...   28.77  NaN   288.0   322.0   2.28 NaN        NaN
# ..       ...     ...  ...     ...  ...     ...     ...    ...  ..        ...
# 74   12928.0     NaN  ...   22.19  NaN     NaN     NaN    NaN NaN        NaN
# 75   44445.0   15.98  ...   16.24  NaN   414.0   311.0   0.37 NaN        NaN
# 76   16371.0   18.19  ...   25.59  NaN   578.0   605.0   0.19 NaN        NaN
# 77       0.0     NaN  ...   28.83  NaN     NaN     NaN    NaN NaN        NaN
# 78    3726.0   63.05  ...   26.32  NaN   627.0   555.0   3.86 NaN        NaN
#
#    Ema20  Ema50  Ema200
# 0    NaN    NaN     NaN
# 1    NaN    NaN     NaN
# 2    NaN    NaN     NaN
# 3    NaN    NaN     NaN
# 4    NaN    NaN     NaN
# ..   ...    ...     ...
# 74   NaN    NaN     NaN
# 75   NaN    NaN     NaN
# 76   NaN    NaN     NaN
# 77   NaN    NaN     NaN
# 78   NaN    NaN     NaN
#
# [79 rows x 28 columns]

# %%
a=x.iloc[0:,24]
a
# Out:
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
#       ..
# 74   NaN
# 75   NaN
# 76   NaN
# 77   NaN
# 78   NaN
# Name:       rsi, Length: 79, dtype: float64

# %%
number=x.shape[0]
y=x.iloc[0,0]
y
# Out:
# 'ACE'

# %%
i=0
e=0
while e <number:
 y=x.iloc[i,0]
 from datetime import datetime
 from datetime import timedelta
 now = datetime.today()
 duration= timedelta(days=300)
 start=now-duration
 s = yfinance.download(y+".BK",start,now)
 rsi = talib.RSI(s["Close"])
 print_rsi=rsi[-1]
 stock_rsi=print_rsi
 if stock_rsi>set_rsi:
   x.iloc[i,24]=stock_rsi
   i+=1
   e+=1
 else  : 
   x = x.drop(e,axis=0)
   x.reset_index(drop=True) # Reset index
   e+=1
print("finish")
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# finish

# %%
x.to_csv('rsi_scan.csv')
x
# Out:
#      Name    No.          Links  Sign    Last  Chg%       Volume  Value (k)  \
# 0     ACE   11.0      i | 1 | 3   NaN    3.92  0.00   93454200.0   365854.0
# 2   APURE   48.0  i | 1 | 2 | 3   NaN    6.20  9.73  138523700.0   869819.0
# 3    ARIP   52.0  i | 1 | 2 | 3   NaN    1.03  0.98   18361100.0    18393.0
# 8     BGC   87.0      i | 1 | 3   NaN   11.50 -2.54    9710100.0   110476.0
# 9     BIZ   92.0  i | 1 | 2 | 3   NaN    9.60 -2.04    2671000.0    25625.0
# 12    CBG  115.0  i | 1 | 2 | 3   NaN  151.50  0.00    4514900.0   681010.0
# 14    CKP  135.0  i | 1 | 2 | 3   NaN    5.90  0.00   71950200.0   431845.0
# 22   DTAC  177.0  i | 1 | 2 | 3   NaN   31.75  2.42   17459200.0   551269.0
# 23    EPG  193.0  i | 1 | 2 | 3   NaN   13.00  0.78   45757400.0   595634.0
# 24   GPSC  228.0  i | 1 | 2 | 3   NaN   79.75 -0.62   21824900.0  1737063.0
# 32  LANNA  319.0  i | 1 | 2 | 3   NaN   18.40  0.55    3943900.0    72541.0
# 36    NDR  381.0  i | 1 | 2 | 3   NaN    3.38 -3.98   12458000.0    42588.0
# 38    NSL  399.0              i   NaN   15.30 -1.29    3545300.0    54049.0
# 46    RWI  493.0      i | 1 | 3   NaN    2.04 -2.86   40685500.0    84860.0
# 52   SCGP  518.0      i | 1 | 3   NaN   64.00 -0.39    5839600.0   373367.0
# 62    SVI  601.0  i | 1 | 2 | 3   NaN    4.88  0.83   15463500.0    76477.0
# 69  TPLAS  676.0      i | 1 | 3   NaN    5.00 -2.91   16328300.0    83010.0
# 73    VIH  734.0  i | 1 | 2 | 3   NaN   12.90 -3.73    3461900.0    44662.0
#
#     MCap (M)     P/E  ... FFloat%  MG%  Magic1  Magic2    PEG  CG        rsi  \
# 0    39890.0   31.30  ...   22.62  NaN   600.0   555.0   0.37 NaN  64.299714
# 2     5941.0   19.25  ...   26.92  NaN   385.0   318.0   0.10 NaN  85.344956
# 3      480.0  135.53  ...   28.67  NaN  1027.0  1036.0  10.89 NaN  64.034897
# 8     7986.0   14.85  ...   27.41  NaN   440.0   579.0   7.33 NaN  62.269328
# 9     3840.0   34.63  ...   24.41  NaN   492.0   625.0   8.41 NaN  60.274988
# 12  151500.0   44.24  ...   28.85  NaN   449.0   445.0   1.45 NaN  66.628302
# 14   47963.0   55.85  ...   24.22  NaN   922.0   936.0   0.78 NaN  58.433739
# 22   75178.0   18.48  ...   29.26  NaN   329.0   627.0  -0.15 NaN  66.467487
# 23   36400.0   29.86  ...   25.90  NaN   578.0   541.0  -7.51 NaN  67.128540
# 24  224873.0   28.46  ...   24.75  NaN   663.0   680.0   0.83 NaN  65.448270
# 32    9660.0   27.54  ...   24.48  NaN   665.0   537.0   1.76 NaN  58.985035
# 36    1141.0   19.53  ...   23.09  NaN   572.0   506.0  -0.22 NaN  66.804436
# 38       0.0     NaN  ...   25.00  NaN     NaN     NaN    NaN NaN  63.886568
# 46    1298.0    5.97  ...   20.01  NaN    64.0    28.0  -0.06 NaN  72.332580
# 52  274747.0   40.05  ...   26.21  NaN   736.0   728.0    NaN NaN  62.885132
# 62   10593.0   17.28  ...   18.66  NaN   365.0   475.0  21.39 NaN  60.025285
# 69    1350.0   35.21  ...   25.73  NaN   598.0   496.0   1.61 NaN  66.707259
# 73    7362.0   36.34  ...   29.03  NaN   559.0   526.0   2.27 NaN  59.773859
#
#    Ema20  Ema50  Ema200
# 0    NaN    NaN     NaN
# 2    NaN    NaN     NaN
# 3    NaN    NaN     NaN
# 8    NaN    NaN     NaN
# 9    NaN    NaN     NaN
# 12   NaN    NaN     NaN
# 14   NaN    NaN     NaN
# 22   NaN    NaN     NaN
# 23   NaN    NaN     NaN
# 24   NaN    NaN     NaN
# 32   NaN    NaN     NaN
# 36   NaN    NaN     NaN
# 38   NaN    NaN     NaN
# 46   NaN    NaN     NaN
# 52   NaN    NaN     NaN
# 62   NaN    NaN     NaN
# 69   NaN    NaN     NaN
# 73   NaN    NaN     NaN
#
# [18 rows x 28 columns]

# %%
#filter code

# %%
#Ema

# %%
a=pd.read_csv('rsi_scan.csv')#เลือกหุ้น
x=a.iloc[0:,1:]
x
# Out:
#      Name    No.          Links  Sign    Last  Chg%       Volume  Value (k)  \
# 0     ACE   11.0      i | 1 | 3   NaN    3.92  0.00   93454200.0   365854.0
# 1   APURE   48.0  i | 1 | 2 | 3   NaN    6.20  9.73  138523700.0   869819.0
# 2    ARIP   52.0  i | 1 | 2 | 3   NaN    1.03  0.98   18361100.0    18393.0
# 3     BGC   87.0      i | 1 | 3   NaN   11.50 -2.54    9710100.0   110476.0
# 4     BIZ   92.0  i | 1 | 2 | 3   NaN    9.60 -2.04    2671000.0    25625.0
# 5     CBG  115.0  i | 1 | 2 | 3   NaN  151.50  0.00    4514900.0   681010.0
# 6     CKP  135.0  i | 1 | 2 | 3   NaN    5.90  0.00   71950200.0   431845.0
# 7    DTAC  177.0  i | 1 | 2 | 3   NaN   31.75  2.42   17459200.0   551269.0
# 8     EPG  193.0  i | 1 | 2 | 3   NaN   13.00  0.78   45757400.0   595634.0
# 9    GPSC  228.0  i | 1 | 2 | 3   NaN   79.75 -0.62   21824900.0  1737063.0
# 10  LANNA  319.0  i | 1 | 2 | 3   NaN   18.40  0.55    3943900.0    72541.0
# 11    NDR  381.0  i | 1 | 2 | 3   NaN    3.38 -3.98   12458000.0    42588.0
# 12    NSL  399.0              i   NaN   15.30 -1.29    3545300.0    54049.0
# 13    RWI  493.0      i | 1 | 3   NaN    2.04 -2.86   40685500.0    84860.0
# 14   SCGP  518.0      i | 1 | 3   NaN   64.00 -0.39    5839600.0   373367.0
# 15    SVI  601.0  i | 1 | 2 | 3   NaN    4.88  0.83   15463500.0    76477.0
# 16  TPLAS  676.0      i | 1 | 3   NaN    5.00 -2.91   16328300.0    83010.0
# 17    VIH  734.0  i | 1 | 2 | 3   NaN   12.90 -3.73    3461900.0    44662.0
#
#     MCap (M)     P/E  ... FFloat%  MG%  Magic1  Magic2    PEG  CG        rsi  \
# 0    39890.0   31.30  ...   22.62  NaN   600.0   555.0   0.37 NaN  64.299714
# 1     5941.0   19.25  ...   26.92  NaN   385.0   318.0   0.10 NaN  85.344956
# 2      480.0  135.53  ...   28.67  NaN  1027.0  1036.0  10.89 NaN  64.034897
# 3     7986.0   14.85  ...   27.41  NaN   440.0   579.0   7.33 NaN  62.269328
# 4     3840.0   34.63  ...   24.41  NaN   492.0   625.0   8.41 NaN  60.274988
# 5   151500.0   44.24  ...   28.85  NaN   449.0   445.0   1.45 NaN  66.628302
# 6    47963.0   55.85  ...   24.22  NaN   922.0   936.0   0.78 NaN  58.433739
# 7    75178.0   18.48  ...   29.26  NaN   329.0   627.0  -0.15 NaN  66.467487
# 8    36400.0   29.86  ...   25.90  NaN   578.0   541.0  -7.51 NaN  67.128540
# 9   224873.0   28.46  ...   24.75  NaN   663.0   680.0   0.83 NaN  65.448270
# 10    9660.0   27.54  ...   24.48  NaN   665.0   537.0   1.76 NaN  58.985035
# 11    1141.0   19.53  ...   23.09  NaN   572.0   506.0  -0.22 NaN  66.804436
# 12       0.0     NaN  ...   25.00  NaN     NaN     NaN    NaN NaN  63.886568
# 13    1298.0    5.97  ...   20.01  NaN    64.0    28.0  -0.06 NaN  72.332580
# 14  274747.0   40.05  ...   26.21  NaN   736.0   728.0    NaN NaN  62.885132
# 15   10593.0   17.28  ...   18.66  NaN   365.0   475.0  21.39 NaN  60.025285
# 16    1350.0   35.21  ...   25.73  NaN   598.0   496.0   1.61 NaN  66.707259
# 17    7362.0   36.34  ...   29.03  NaN   559.0   526.0   2.27 NaN  59.773859
#
#    Ema20  Ema50  Ema200
# 0    NaN    NaN     NaN
# 1    NaN    NaN     NaN
# 2    NaN    NaN     NaN
# 3    NaN    NaN     NaN
# 4    NaN    NaN     NaN
# 5    NaN    NaN     NaN
# 6    NaN    NaN     NaN
# 7    NaN    NaN     NaN
# 8    NaN    NaN     NaN
# 9    NaN    NaN     NaN
# 10   NaN    NaN     NaN
# 11   NaN    NaN     NaN
# 12   NaN    NaN     NaN
# 13   NaN    NaN     NaN
# 14   NaN    NaN     NaN
# 15   NaN    NaN     NaN
# 16   NaN    NaN     NaN
# 17   NaN    NaN     NaN
#
# [18 rows x 28 columns]

# %%
stock_ema=x.iloc[0:,25] #first stock in ema
stock_ema
# Out:
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# 5    NaN
# 6    NaN
# 7    NaN
# 8    NaN
# 9    NaN
# 10   NaN
# 11   NaN
# 12   NaN
# 13   NaN
# 14   NaN
# 15   NaN
# 16   NaN
# 17   NaN
# Name: Ema20, dtype: float64

# %%
#เทสEMA

# %%
 number=x.shape[0]
 y=x.iloc[0,0]
y
# Out:
# 'ACE'

# %%
i=0
e=0
while e <number:
  y=x.iloc[i,0]
  end = datetime.today()
  duration= timedelta(days=365)
  start=end-duration
  s = web.DataReader(y+".BK", 'yahoo', start, end)
  close_array=s.iloc[0:,3:-2]
  close_array['EMA'] = talib.EMA(close_array['Close'], timeperiod =set_ema0)
  close_data = close_array.iloc[-1,0]
  ema_data0 =close_array.iloc[-1,1]
  stock_ema0 = ema_data0
  close_array['EMA'] = talib.EMA(close_array['Close'], timeperiod =set_ema1)
  ema_data1 =close_array.iloc[-1,1]
  stock_ema1 = ema_data1
  close_array['EMA'] = talib.EMA(close_array['Close'], timeperiod =set_ema2)
  ema_data2 =close_array.iloc[-1,1]
  stock_ema2 = ema_data2
  if close_data > stock_ema0 and close_data > stock_ema1 and close_data > stock_ema2 :
   x.iloc[i,25]=stock_ema0
   x.iloc[i,26]=stock_ema1
   x.iloc[i,27]=stock_ema2
   i+=1
   e+=1
  else  : 
   x = x.drop(e,axis=0)
   x.reset_index(drop=True) # Reset index
   e+=1
print("finish")
# Out:
# finish

# %%
x.to_csv('finish_scan.csv')
x
# Out:
#      Name    No.          Links  Sign    Last  Chg%       Volume  Value (k)  \
# 0     ACE   11.0      i | 1 | 3   NaN    3.92  0.00   93454200.0   365854.0
# 1   APURE   48.0  i | 1 | 2 | 3   NaN    6.20  9.73  138523700.0   869819.0
# 2    ARIP   52.0  i | 1 | 2 | 3   NaN    1.03  0.98   18361100.0    18393.0
# 3     BGC   87.0      i | 1 | 3   NaN   11.50 -2.54    9710100.0   110476.0
# 4     BIZ   92.0  i | 1 | 2 | 3   NaN    9.60 -2.04    2671000.0    25625.0
# 5     CBG  115.0  i | 1 | 2 | 3   NaN  151.50  0.00    4514900.0   681010.0
# 6     CKP  135.0  i | 1 | 2 | 3   NaN    5.90  0.00   71950200.0   431845.0
# 8     EPG  193.0  i | 1 | 2 | 3   NaN   13.00  0.78   45757400.0   595634.0
# 9    GPSC  228.0  i | 1 | 2 | 3   NaN   79.75 -0.62   21824900.0  1737063.0
# 10  LANNA  319.0  i | 1 | 2 | 3   NaN   18.40  0.55    3943900.0    72541.0
# 11    NDR  381.0  i | 1 | 2 | 3   NaN    3.38 -3.98   12458000.0    42588.0
# 13    RWI  493.0      i | 1 | 3   NaN    2.04 -2.86   40685500.0    84860.0
# 15    SVI  601.0  i | 1 | 2 | 3   NaN    4.88  0.83   15463500.0    76477.0
# 16  TPLAS  676.0      i | 1 | 3   NaN    5.00 -2.91   16328300.0    83010.0
# 17    VIH  734.0  i | 1 | 2 | 3   NaN   12.90 -3.73    3461900.0    44662.0
#
#     MCap (M)     P/E  ... FFloat%  MG%  Magic1  Magic2    PEG  CG        rsi  \
# 0    39890.0   31.30  ...   22.62  NaN   600.0   555.0   0.37 NaN  64.299714
# 1     5941.0   19.25  ...   26.92  NaN   385.0   318.0   0.10 NaN  85.344956
# 2      480.0  135.53  ...   28.67  NaN  1027.0  1036.0  10.89 NaN  64.034897
# 3     7986.0   14.85  ...   27.41  NaN   440.0   579.0   7.33 NaN  62.269328
# 4     3840.0   34.63  ...   24.41  NaN   492.0   625.0   8.41 NaN  60.274988
# 5   151500.0   44.24  ...   28.85  NaN   449.0   445.0   1.45 NaN  66.628302
# 6    47963.0   55.85  ...   24.22  NaN   922.0   936.0   0.78 NaN  58.433739
# 8    36400.0   29.86  ...   25.90  NaN   578.0   541.0  -7.51 NaN  67.128540
# 9   224873.0   28.46  ...   24.75  NaN   663.0   680.0   0.83 NaN  65.448270
# 10    9660.0   27.54  ...   24.48  NaN   665.0   537.0   1.76 NaN  58.985035
# 11    1141.0   19.53  ...   23.09  NaN   572.0   506.0  -0.22 NaN  66.804436
# 13    1298.0    5.97  ...   20.01  NaN    64.0    28.0  -0.06 NaN  72.332580
# 15   10593.0   17.28  ...   18.66  NaN   365.0   475.0  21.39 NaN  60.025285
# 16    1350.0   35.21  ...   25.73  NaN   598.0   496.0   1.61 NaN  66.707259
# 17    7362.0   36.34  ...   29.03  NaN   559.0   526.0   2.27 NaN  59.773859
#
#          Ema20       Ema50      Ema200
# 0     3.833774    3.763380    3.563184
# 1     4.881783    4.570341    3.320538
# 2     0.936660    0.833555    0.611221
# 3    11.129131   10.662512   10.541135
# 4     9.075284    7.734639    5.203406
# 5   147.424425  139.631232  129.401540
# 6     5.675990    5.522283    5.180467
# 8    12.236341   11.674395    8.797072
# 9    76.584775   75.059844   71.721049
# 10   16.678191   14.756289   10.134088
# 11    3.153284    2.970987    2.150544
# 13    1.877471    1.762328    1.501685
# 15    4.850994    4.878854    4.671564
# 16    4.431785    3.547633    2.298068
# 17   12.525213   11.096261    8.561036
#
# [15 rows x 28 columns]
